# %% [markdown]
# ## Triggering Failures: Out-Of-Distribution detection by learning from local adversarial attacks in Semantic Segmentation

# %% [markdown]
# ### Gradually training an ObsNet on a single image

# %%
# %cd /Data/EA/obsnet/
# %run -i 'main.py' --dset_folder "/Data/EA/obsnet/CamSeq" --segnet_file "SegNet.pth" --obsnet_file "./ckpt/camvid/" --data "CamVid" --tboard "./logs/camvid" --num_workers 10 --bsize 1 --adv "max_random_patch" --epsilon 0.025 --lr 0.2 --epoch 4
# Out:
# /Data/EA/obsnet
# Clearing cache
# ######## Epoch: 0 || Time: 0.00 min ########
# Train loss: 0.7421, Progress: 0.00%
# Epoch Summary: Train Avg loss: 0.7421, ObsNet acc: 82.67, SegNet acc: 82.67
# Val ObsNet: Fpr_at_95tpr 87.7, Aupr sucess: 89.5, Aupr error: 22.5, Roc: 60.8,  Ace 0.675
# Epoch Summary: Val Avg loss: 0.7379, ObsNet acc: 82.66, SegNet acc: 82.66
# save best net!!!
# ######## Epoch: 1 || Time: 0.21 min ########
# Train loss: 0.7327, Progress: 0.00%
# Epoch Summary: Train Avg loss: 0.7327, ObsNet acc: 78.06, SegNet acc: 78.06
# Val ObsNet: Fpr_at_95tpr 84.0, Aupr sucess: 90.3, Aupr error: 27.8, Roc: 64.0,  Ace 0.669
# Epoch Summary: Val Avg loss: 0.7288, ObsNet acc: 82.66, SegNet acc: 82.66
# save best net!!!
# ######## Epoch: 2 || Time: 0.40 min ########
# Train loss: 0.6601, Progress: 0.00%
# Epoch Summary: Train Avg loss: 0.6601, ObsNet acc: 82.56, SegNet acc: 82.56
# Val ObsNet: Fpr_at_95tpr 89.4, Aupr sucess: 90.9, Aupr error: 25.4, Roc: 65.1,  Ace 0.666
# ...

# %% [markdown]
# ### Visualizing uncertainties with Gaussian perturbation method and ODIN (Outlier Detection in Neural Network)

# %%
# %cd /Data/EA/obsnet/
# %run -i 'main.py' --dset_folder "/Data/EA/obsnet/CamSeq" --segnet_file "SegNet.pth" --obsnet_file "./ckpt/camvid/" --data "CamVid" --tboard "./logs/camvid" --num_workers 10 --bsize 1 --adv "max_random_patch" --epsilon 0.025 --lr 0.2 --epoch 2 --test_multi "obsnet,gauss,odin"
# Out:
# /Data/EA/obsnet
# Clearing cache
# ######## Epoch: 0 || Time: 0.00 min ########
# Train loss: 0.8714, Progress: 0.00%
# Epoch Summary: Train Avg loss: 0.8714, ObsNet acc: 47.42, SegNet acc: 74.59
# Eval loss: 0.8225, Progress: 0.00%
# Val Gauss: Fpr_at_95tpr 56.5, Aupr sucess: 96.3, Aupr error: 53.8, Roc: 85.7,  Ace 0.165
# Val Odin: Fpr_at_95tpr 79.2, Aupr sucess: 93.5, Aupr error: 31.4, Roc: 72.1,  Ace 0.289
# Val ObsNet: Fpr_at_95tpr 97.0, Aupr sucess: 84.7, Aupr error: 12.1, Roc: 41.4,  Ace 0.659
# Epoch Summary: Val Avg loss: 0.8225, ObsNet acc: 14.69, SegNet acc: 85.81
# save best net!!!
# ######## Epoch: 1 || Time: 0.37 min ########
# Train loss: 0.8276, Progress: 0.00%
# Epoch Summary: Train Avg loss: 0.8276, ObsNet acc: 58.10, SegNet acc: 73.16
# Eval loss: 0.8179, Progress: 0.00%
# Val Gauss: Fpr_at_95tpr 56.4, Aupr sucess: 96.3, Aupr error: 53.8, Roc: 85.7,  Ace 0.165
# Val Odin: Fpr_at_95tpr 79.2, Aupr sucess: 93.5, Aupr error: 31.4, Roc: 72.1,  Ace 0.289
# ...
